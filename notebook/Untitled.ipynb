# %%
import pandas

df = pandas.read_csv("../data.csv", encoding="latin-1")
df
# Out:
#                                             song_name  \
# 0                  See You Again (feat. Charlie Puth)
# 1                                          Trap Queen
# 2                           Watch Me (Whip / Nae Nae)
# 3                               679 (feat. Remy Boyz)
# 4                                       Hotline Bling
# 5                                   Time of Our Lives
# 6               GDFR (feat. Sage The Gemini & Lookas)
# 7                                My Way (feat. Monty)
# 8                                     Nasty Freestyle
# 9                                                Only
# 10                              I Don't Fuck With You
# 11                               Flex (Ooh, Ooh, Ooh)
# 12                                     Truffle Butter
# 13  All Eyes On You (feat. Chris Brown & Nicki Minaj)
# 14                                          Blessings
# 15                                            No Type
# ...
